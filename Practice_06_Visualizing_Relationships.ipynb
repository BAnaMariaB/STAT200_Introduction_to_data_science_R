# %% [markdown]
# # **Practice 06: Visualizing Relationships**
#
# #### **WRITE YOUR NAME HERE**

# %% [markdown]
# ---
#
# **IMPORTANT**:
# - Before starting the lab, save a copy to your google drive by navigating to `File > Save a copy in Drive` <br>
#
# <br>
#
#
# **Instructions**: Complete the lab below.
#
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Include markdown cells with written answers explaining your work when prompted
# - **NOTE: Your completed lab must be submitted to Canvas as a .ipynb file by the end of the lab session**
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ####<font color=red>Organized</font>
#
# **Answers should be organized in the following format for organization and readability**

# %% [markdown]
# <font color=red>Example task 1</font>

# %%
# 1.

# This will be the code block to answer the first part of a task

# %% [markdown]
# 1. This will be the text answer/explanation (if prompted) for the first task

# %% [markdown]
# <font color=red>Example task 2</font>

# %%
# 2.

# This will be the code block to answer the second part of a task

# %% [markdown]
# 2. This will be the text answer/explanation (if prompted) for the second task

# %% [markdown]
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>

# %% [markdown]
# ---
#
# <br>

# %% [markdown]
# #### Packages

# %%
# install packages for today's lecture
install.packages("pheatmap")  # package for heatmap
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# load the necessary packages
library(pheatmap)

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 1</font> - Loading and Preprocessing the Dataset

# %% [markdown]
# <font color=red>Task 1.1</font> Today, we'll be working with salary data available online. Run the following script to load the salary dataset for today's assignment.
#
# ```
# data_url <- "https://raw.githubusercontent.com/khasenst/datasets_teaching/refs/heads/main/salary_data.csv"
# salary   <- read.csv(data_url, header = TRUE)
# ```

# %%
#1.1
data_url <- "https://raw.githubusercontent.com/khasenst/datasets_teaching/refs/heads/main/salary_data.csv"
salary   <- read.csv(data_url, header = TRUE)

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.2</font> View the first few lines of the `salary` data frame using the `head()` function.

# %%
#1.2
head(salary)
# Out:
#   Age Gender Education.Level Job.Title         Years.of.Experience Salary
# 1 32  Male   Bachelor's      Software Engineer  5                   90000
# 2 28  Female Master's        Data Analyst       3                   65000
# 3 45  Male   PhD             Senior Manager    15                  150000
# 4 36  Female Bachelor's      Sales Associate    7                   60000
# 5 52  Male   Master's        Director          20                  200000
# 6 29  Male   Bachelor's      Marketing Analyst  2                   55000

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.3</font> Use the `str()` function to determine the number of rows and columns in the `salary` data frame. Write your observations in a text cell.

# %%
#1.3
str(salary)
# Out:
# 'data.frame':	6704 obs. of  6 variables:
#  $ Age                : int  32 28 45 36 52 29 42 31 26 38 ...
#  $ Gender             : chr  "Male" "Female" "Male" "Female" ...
#  $ Education.Level    : chr  "Bachelor's" "Master's" "PhD" "Bachelor's" ...
#  $ Job.Title          : chr  "Software Engineer" "Data Analyst" "Senior Manager" "Sales Associate" ...
#  $ Years.of.Experience: num  5 3 15 7 20 2 12 4 1 10 ...
#  $ Salary             : int  90000 65000 150000 60000 200000 55000 120000 80000 45000 110000 ...

# %% [markdown]
# **Task 1.3**<br>
# We have 6 variables/ collums and 6704 rows/objects.

# %% [markdown]
# <font color=red>Task 1.4</font>
#
# * Convert the `Gender` and `Education.Level` variables in factors and insert them in the data frame. You may overwrite the existing `Gender` and `Education.Level` variables
# * Is the `Gender` variable a nominal or ordinal categorical variable?
# * Is the `Education.Level` variable a nominal or ordinal categorical variable?

# %%
#1.4
salary$Gender <- as.factor(salary$Gender)
salary$Education.Level <- as.factor(salary$Education.Level)

# %% [markdown]
# **Task 1.4**<br>
# The gender variable is nominal categorical variable, since there is no order between genders. <br>
# The Education.Level variable is a ordinal categorical variable, since there is an orger between education levels.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.5</font> Use the `levels()` function to view the unique categories of the `Education.Level` variable. What issues do you observe?

# %%
#1.5
levels(salary$Education.Level)
# Out:
# [1] ""                  "Bachelor's"        "Bachelor's Degree"
# [4] "High School"       "Master's"          "Master's Degree"
# [7] "phD"               "PhD"

# %% [markdown]
# **Taks 1.5** <br>
# There are a couple of categories that are not unique such as Bachelor\s or Bachelor\s Degree, or phd or PHD, or Master\s or Master\s Degree.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.6</font> Edit the levels of the `Education.Level` variable to the following:
#
# * "missing"
# * "BS"
# * "HS"
# * "MS"
# * "PhD"
#
# Hint: `levels(salary$Education.Level) <-  c(...)`

# %%
#1.6
levels(salary$Education.Level) <- c("Missing", "BS", "BS","HS","MS","MS","PhD","PhD")

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.7</font> Reorder the levels so that they are in order of the level of education.
#
# Hint: `factor(salary$Education.Level, levels = c("missing", "HS", "BS", "MS", "PhD"))`

# %%
#1.7
factor(salary$Education.Level, levels = c("missing","HS","BS","MS","PhD"))
# Out:
#    [1] BS   HS   MS   BS   HS   BS   HS   BS   BS   MS   HS   BS   BS   HS
#   [15] BS   BS   HS   MS   BS   BS   HS   HS   BS   BS   HS   BS   HS   BS
#   [29] MS   HS   BS   BS   HS   BS   MS   BS   BS   HS   BS   BS   HS   HS
#   [43] BS   BS   HS   BS   BS   HS   MS   BS   BS   HS   BS   HS   BS   BS
#   [57] HS   MS   BS   HS   HS   BS   BS   MS   BS   HS   BS   BS   HS   HS
#   [71] BS   BS   MS   BS   HS   BS   BS   HS   HS   BS   BS   HS   BS   MS
#   [85] BS   HS   BS   BS   HS   BS   MS   BS   BS   HS   BS   BS   MS   BS
#   [99] HS   BS   BS   HS   HS   BS   HS   MS   BS   BS   HS   BS   HS   BS
#  [113] BS   HS   BS   HS   BS   MS   BS   HS   BS   HS   BS   BS   MS   BS
#  [127] HS   BS   BS   HS   HS   BS   HS   MS   BS   BS   HS   BS   BS   HS
#  [141] BS   HS   BS   BS   HS   BS   MS   BS   BS   HS   BS   HS   MS   BS
#  [155] HS   BS   BS   HS   MS   BS   BS   HS   BS   BS   HS   BS   BS   MS
#  [169] BS   HS   HS   BS   <NA> BS   HS   BS   MS   BS   BS   HS   BS   HS
#  [183] MS   BS   BS   BS   HS   BS   MS   BS   BS   HS   BS   BS   HS   BS
#  [197] BS   MS   BS   HS   HS   BS   BS   HS   BS   MS   BS   BS   HS   BS
   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6483] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6497] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6511] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6525] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6539] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6553] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6567] BS   MS   BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# [6581] HS   BS   MS   BS   BS   HS   BS   BS   MS   HS   BS   BS   MS   BS
# [6595] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6609] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6623] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6637] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6651] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6665] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6679] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS   BS   MS
# [6693] BS   HS   BS   BS   MS   HS   BS   MS   BS   BS   HS   BS
# Levels: missing HS BS MS PhD
# [1] "Missing" "BS"      "HS"      "MS"      "PhD"

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 2</font> - Scatterplots

# %% [markdown]
# <font color=red>Task 2.1</font> Plot a scatterplot with `Salary` on the y-axis and `Age` on the x-axis. Be sure to label your x-axis and y-axis accordingly using the `xlab` and `ylab` arguments in the `plot()` function.

# %%
#2.1
plot(  salary$Age, salary$Salary,
        xlab = "Age",
        ylab = "Salary",
        main = "Age vs Salary"
)
# Out:
# Plot with title “Age vs Salary”

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.2</font> In a text cell, write your observations from the scatterplot from Task 2.1.
#
# For example,
#   * Is there a relationship between salary and age?
#   * Is the relationship linear?
#   * What is the approximate average salary of an individual who is in their mid 20's?
#   * What is the approximate average salary of an individual who is in their mid 50's?
#   * Which age has the highest variability in salary?

# %% [markdown]
# **Task 2.2** <br>
#
# * Yes there seems to be a linear relationship between salary and age. It looks like when age increases the salary also seems to be increasing.
#
# * The relationsip looks sort of linear, but it does seem to have a curveture. The salary increase seems to slow down as the age progresses.
#
# * The approximate average salary of an individual who is in their mid 20's is 75 000$.
#
# * The approximate average salary of an individual who is in their mid 50's is 175 000$.
#
# * The highest variability in salary appears to be between 25-35 years old, oscilating from 20 000 to 200 000.

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 3</font> - Boxplots

# %% [markdown]
# <font color=red>Task 3.1</font> Plot a boxplot with `Salary` on the y-axis and `Gender` on the x-axis. Be sure to label you x-axis and y-axis accordingly using the `xlab` and `ylab` arguments in the `boxplot()` function.

# %%
#3.1
boxplot(salary$Salary ~ salary$Gender,
        xlab = "Gender",
        ylab = "Salary",
        main = "Salary vs Gender")
# Out:
# Plot with title “Salary vs Gender”

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.2</font> In a text cell, write your observations from the boxplot from Task 3.1. Include observations about the medians, quartiles, and variability for female and male individuals.

# %% [markdown]
# **Task 3.2** <br>
#
#  * Medians: The median salary for Male individuals is higher than that for Female individuals.The Other gender category has the highest median salary among all three groups.
#
# * Interquartile Range and Spread: The Male category has a wider IQR than the Female category,so more variability in salary distribution. The Other category has a narrowerer IQR, salaries in this group are more consistent.
#
# * Variability: The Male group has the widest salary range, with whiskers extending from very low salaries to the highest recorded salary in the dataset. The Female category has a slightly lower upper whisker compared to males, showing that the highest salaries in this group are lower than those in the male category.The Other category has a relatively short range, with salaries clustering towards the upper end.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.3</font> Plot a boxplot with `Salary` on the y-axis and `Education.Level` on the x-axis. Be sure to label your x-axis and y-axis accordingly using the `xlab` and `ylab` arguments in the `boxplot()` function.

# %%
#3.3
boxplot(salary$Salary ~ salary$Education.Level,
        xlab = "Education Level",
        ylab = "Salary",
        main = "Salary vs Education Level")
# Out:
# Plot with title “Salary vs Education Level”

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.4</font> In a text cell, write your observations from the boxplot from Task 3.3. Include observations about the medians, quartiles, variability, and outliers.

# %% [markdown]
# **Task 3.4** <br>
#
#
# * Medians: The median salary increases as education level rises.The MS category has the highest median salary. The Missing category has a fixed salary with no variability, there doesn't appear to be much else information about it. The median salary for individuals with a MS degree is higher than those with a BS or HS education.
#
# * Interquartile Range (IQR) : The BS, HS, and MS categories have wider IQRs, indicating a larger spread in salary distributions. with BS having the larges IQR. The HS and MS category seem to have a normal distribution.The BS category has a left skewed distribution.
#
# * Outliers:The MS category has multiple outliers at the lower salary end.The BS categories also has one outlier.
#
# * PhD : they seem to be missing all information about this category.

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 4</font> - Heatmaps

# %% [markdown]
# <font color=red>Task 4.1</font> Create a heatmap from a frequency table with `Job.Title` and `Education.Level` as the variables.
#
# You can use the following code to adjust the width and height of the plot:
# `options(repr.plot.width=15, repr.plot.height=35)`

# %%
#4.1
options(repr.plot.width=15, repr.plot.height=35)

data <- table(salary$Job.Title, salary$Education.Level)

pheatmap(data,
         col = colorRampPalette(c("white", "red"))(256)  # specifies color range for heatmap
         )
# Out:
# plot without title

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 4.2</font> Write your observations in a text cell.
#
# * In this dataset, what are the most common jobs amongst individuals with HS degrees? BS degrees? MS degrees? PhD degrees?
# * Is there anything else you observe from the heatmap?

# %% [markdown]
# **Task 4.2** <br>
#
# * The most common jobs are , with a HS degree are Marketing Manager,Full Stack Engineer Senior Software engineer, with a BS degree are Software engineer and data analyst, with a MS degree are Data Scientist and Software engineer manager, with a PhD degree there is no information.
#
# * it is quit odd that there is no information on the PhD's. Could be tha there was a problem in renaming the categories earlier on. Or maybe ther is not information on the PhDs.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 4.3</font> Run the following script, which creates a new data frame called `salary_common`. This new data frame only includes the common job titles.
#
# ```
# job_table     <- table(salary$Job.Title)
# salary_common <- salary[salary$Job.Title %in% (names(job_table)[job_table > 100]),]
# ```
#
# * Replot your heatmap using the data frame `salary_common`

# %%
#4.1
job_table <- table(salary$Job.Title)
salary_common <- salary[salary$Job.Title %in% names(job_table)[job_table > 100],]

data <- table(salary_common$Job.Title, salary_common$Education.Level)

pheatmap(data,
         col = colorRampPalette(c("white", "red"))(256)
)
# Out:
# plot without title

# %% [markdown]
# <br>
#
# <br>
